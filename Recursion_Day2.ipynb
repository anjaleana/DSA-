# %%
def fun1(x,y):
    if x==0:
        return y
    else:
        return fun1(x-1,x+y)
print(fun1(5,2))
# Out:
# 17

# %% [markdown]
# #### How it works

# %% [markdown]
# ![IMG_20221015_164648_2.jpg](attachment:IMG_20221015_164648_2.jpg)

# %% [markdown]
# ![IMG_20221015_164655_2.jpg](attachment:IMG_20221015_164655_2.jpg)
